# %% [markdown]
# #### This file shows the ability to use API to get data, structure it in a dataframe, and store it in a SQL database.
#
# - Used the following libraries:
# - To make an API request - requests
# - To decode JSON - json
# - To save data to a dataframe - pandas
# - To interact with an SQL database - sqlalchemy

# %%
# Importing package to make API requests
import requests

# Importing json package to decode JSON
import json

# Importing pandas for ease of use
import pandas as pd

# Importing package to interact with sql database
from sqlalchemy import create_engine

# %% [markdown]
# ### Making a single API request and saving the results to the nyt_article table

# %% [markdown]
# Setting a variable to store the API endpoint URL

# %%
# Key is being redacted
art_key = '********'

# %%
articles_endpoint_url =  f'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key={art_key}'

# %% [markdown]
# Setting a dict of parameters to pass to the API endpoint URL

# %%
params = {'api-key':art_key, 'page':0, 'begin_date':'20210101', 'end_date':'20211231'}

# %% [markdown]
# Making an API GET request with the defined API endpoint URL and the dict of parameters

# %%
articles_api_request = requests.get(articles_endpoint_url,params)

# %% [markdown]
# Confirming the API request received a 200 HTTP status code

# %%
articles_api_request
# Out:
# <Response [200]>

# %% [markdown]
# Viewing the text in the API request result

# %%
articles_api_request.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2022 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"Ali Alexander, who was a key figure in the “Stop the Steal” movement, said he had received a grand jury subpoena and would assist the expanding investigation.","web_url":"https://www.nytimes.com/2022/04/08/us/politics/january-6-investigation-ali-alexander.html","snippet":"Ali Alexander, who was a key figure in the “Stop the Steal” movement, said he had received a grand jury subpoena and would assist the expanding investigation.","lead_paragraph":"Ali Alexander, a prominent organizer of pro-Trump events after the 2020 election, has agreed to cooperate with the Justice Department’s investigation of the attack on the Capitol last year, the first high-profile political figure known to have offered assistance to the government’s newly expanded criminal inquiry.","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-articleLarge.jpg","height":400,"width":600,"legacy":{"xlarge":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-articleLarge.jpg","xlargewidth":600,"xlargeheight":400},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-popup.jpg","height":434,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog480.jpg","height":320,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog533.jpg","height":356,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog427.jpg","height":285,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-tmagSF.jpg","height":241,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-tmagArticle.jpg","height":395,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-slide.jpg","height":400,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-jumbo.jpg","height":683,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-superJumbo.jpg","height":1366,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog225.jpg","height":150,"width":225,"legacy":{},"subType":"blog225","crop_name":"blog225"},{"rank":0,"subtype":"master1050","caption":null,"credit":null,"type":"image","url":"images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master1050.jpg","height":700,"width":1050,"legacy":{},"subType":"master1050","crop_name":"master1050"},{"rank":0,"subtype":"ma ...

# %% [markdown]
# Decoding the API result text as JSON

# %%
json.loads(articles_api_request.text)
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'Ali Alexander, who was a key figure in the “Stop the Steal” movement, said he had received a grand jury subpoena and would assist the expanding investigation.',
#     'web_url': 'https://www.nytimes.com/2022/04/08/us/politics/january-6-investigation-ali-alexander.html',
#     'snippet': 'Ali Alexander, who was a key figure in the “Stop the Steal” movement, said he had received a grand jury subpoena and would assist the expanding investigation.',
#     'lead_paragraph': 'Ali Alexander, a prominent organizer of pro-Trump events after the 2020 election, has agreed to cooperate with the Justice Department’s investigation of the attack on the Capitol last year, the first high-profile political figure known to have offered assistance to the government’s newly expanded criminal inquiry.',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-articleLarge.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-popup.jpg',
#       'height': 434,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog533.jpg',
#       'height': 356,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-superJumbo.jpg',
#       'height': 1366,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master315.jpg',
#       'height': 210,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-master768.jpg',
#       'height': 512,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumSquareAt3X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumSquareAt3X.jpg',
#       'height': 1801,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mediumSquareAt3X',
#       'crop_name': 'mediumSquareAt3X'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-horizontalMediumAt2X.jpg',
#       'height': 4385,
#       'width': 6574,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-hpLarge.jpg',
#       'height': 288,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-threeByTwoLargeAt2X.jpg',
#       'height': 4385,
#       'width': 6574,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-threeByTwoMediumAt2X.jpg',
#       'height': 1001,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine3000.jpg',
#       'height': 1688,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoSixteenByNineJumbo1600.jpg',
#       'height': 901,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-verticalTwoByThree735.jpg',
#       'height': 1103,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'mobileMasterAt3x',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-investigate1/08dc-investigate1-mobileMasterAt3x.jpg',
#       'height': 1201,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mobileMasterAt3x',
#       'crop_name': 'mobileMasterAt3x'}],
#     'headline': {'main': 'Pro-Trump Rally Planner Is Cooperating in Justice Dept.’s Jan. 6 Inquiry',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Rally Planner Will Cooperate In Riot Inquiry',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Alexander, Ali (Ali Abdul Akbar)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Storming of the US Capitol (Jan, 2021)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'United States Politics and Government',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Justice Department',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Right-Wing Extremism and Alt-Right',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Project: Democracy',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Fringe Groups and Movements',
#       'rank': 7,
#       'major': 'N'}],
#     'pub_date': '2022-04-08T22:55:13+0000',
#     'document_type': 'article',
#     'news_desk': 'Washington',
#     'section_name': 'U.S.',
#     'subsection_name': 'Politics',
#     'byline': {'original': 'By Alan Feuer',
#      'person': [{'firstname': 'Alan',
#        'middlename': None,
#        'lastname': 'Feuer',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/5f770148-e8e9-57c9-a5b6-83f55f7cd6e0',
#     'word_count': 1277,
#     'uri': 'nyt://article/5f770148-e8e9-57c9-a5b6-83f55f7cd6e0'},
#    {'abstract': 'In a message two days after Election Day 2020, the president’s son conveyed a range of ideas for keeping his father in office.',
#     'web_url': 'https://www.nytimes.com/2022/04/08/us/politics/donald-trump-jr-meadows-text-message.html',
#     'snippet': 'In a message two days after Election Day 2020, the president’s son conveyed a range of ideas for keeping his father in office.',
#     'lead_paragraph': 'Former President Donald J. Trump’s eldest son sent the White House chief of staff a text message two days after Election Day in 2020 that laid out strategies for declaring his father the winner regardless of the electoral outcome, people familiar with the exchange said on Friday.',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-articleLarge.jpg',
#       'height': 377,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 377},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-popup.jpg',
#       'height': 408,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-blog480.jpg',
#       'height': 301,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-blog533.jpg',
#       'height': 335,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-blog427.jpg',
#       'height': 268,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-tmagSF.jpg',
#       'height': 227,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-tmagArticle.jpg',
#       'height': 372,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-slide.jpg',
#       'height': 377,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-jumbo.jpg',
#       'height': 643,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-superJumbo.jpg',
#       'height': 1286,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-blog225.jpg',
#       'height': 141,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master1050.jpg',
#       'height': 659,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master675.jpg',
#       'height': 424,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master495.jpg',
#       'height': 311,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master180.jpg',
#       'height': 113,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'master315',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master315.jpg',
#       'height': 198,
#       'width': 315,
#       'legacy': {},
#       'subType': 'master315',
#       'crop_name': 'master315'},
#      {'rank': 0,
#       'subtype': 'master768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-master768.jpg',
#       'height': 482,
#       'width': 768,
#       'legacy': {},
#       'subType': 'master768',
#       'crop_name': 'master768'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-thumbStandard.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-thumbStandard.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-smallSquare168.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-smallSquare252.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'mediumSquareAt3X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumSquareAt3X.jpg',
#       'height': 1801,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mediumSquareAt3X',
#       'crop_name': 'mediumSquareAt3X'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-sfSpan.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-largeHorizontalJumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'horizontalMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-horizontalMediumAt2X.jpg',
#       'height': 2719,
#       'width': 4077,
#       'legacy': {},
#       'subType': 'horizontalMediumAt2X',
#       'crop_name': 'horizontalMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-hpLarge.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-largeWidescreen573.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-threeByTwoLargeAt2X.jpg',
#       'height': 2719,
#       'width': 4077,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/08dc-texts-meadows-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-articleInline.jpg',
#       'height': 119,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/us/politics/08dc-texts-meadows/merlin_179573724_98c6845c-d6e1-4bbe-8aeb-6c8109aa4d9a-hpSmall.jpg',
#       'height': 102,
#       'width': 163,
#       'legacy': {},
# ...
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-threeByTwoLargeAt2X.jpg',
#       'height': 4293,
#       'width': 6439,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine3000.jpg',
#       'height': 1687,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/merlin_205182978_4a9dbe2e-66ad-4c4c-80e8-db5268a72199-verticalTwoByThree735.jpg',
#       'height': 1102,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'mobileMasterAt3x',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2022/04/08/world/08ukraine-blog-header-615am-est/08ukraine-blog-header-615am-est-mobileMasterAt3x.jpg',
#       'height': 1800,
#       'width': 1800,
#       'legacy': {},
#       'subType': 'mobileMasterAt3x',
#       'crop_name': 'mobileMasterAt3x'}],
#     'headline': {'main': 'Missile Strike Kills at Least 50 at Train Station in Eastern Ukraine',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Russian Invasion of Ukraine (2022)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Donetsk (Ukraine)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Kramatorsk (Ukraine)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'glocations', 'value': 'Ukraine', 'rank': 4, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'War and Armed Conflicts',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Civilian Casualties',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '2022-04-08T21:50:29+0000',
#     'document_type': 'multimedia',
#     'news_desk': '',
#     'section_name': 'World',
#     'subsection_name': 'Europe',
#     'byline': {'original': 'By Nailah Morgan, Sarah Kerr and Rex Sakamoto',
#      'person': [{'firstname': 'Nailah',
#        'middlename': None,
#        'lastname': 'Morgan',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1},
#       {'firstname': 'Sarah',
#        'middlename': None,
#        'lastname': 'Kerr',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 2},
#       {'firstname': 'Rex',
#        'middlename': None,
#        'lastname': 'Sakamoto',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 3}],
#      'organization': None},
#     'type_of_material': 'Video',
#     '_id': 'nyt://video/e2346a7e-c093-5887-9507-0d62be07525a',
#     'word_count': 0,
#     'uri': 'nyt://video/e2346a7e-c093-5887-9507-0d62be07525a'}],
#   'meta': {'hits': 13327, 'offset': 0, 'time': 9}}}

# %% [markdown]
# Assigning the decoded API request JSON result to a variable

# %%
articles_api_response = json.loads(articles_api_request.text)

# %% [markdown]
# Printing out the dictionary value for the key containing the list of articles in the decoded API request JSON result

# %%
# Verifying the type is indeed a dictionary
type(articles_api_response)
# Out:
# dict

# %%
articles_api_response['response'].keys()
# Out:
# dict_keys(['docs', 'meta'])

# %% [markdown]
# Assigning the list of articles to a variable that will be later used to loop through

# %%
articles_list = articles_api_response['response']['docs']

# %% [markdown]
# Confirming the type of variable for the list of articles variable

# %%
type(articles_list)
# Out:
# list

# %%
article_dict = {
'nyt_article_id':[], 
'web_url': [], 
'main_headline': [],
'document_type': [],
'pub_date': [],
'word_count': [],
'type_of_material': []
}

# %% [markdown]
# - Creating a dictionary to hold the article details. Initializing the dictionary values to an empty list for each key.
#
#
# - Looping through the articles
#     - Assigning the JSON values that will be eventually stored in a table to a variable
#     - Converting the pub_date to a [datetime format]
#     - Appending the variable to the appropriate key for the dictionary initialized above
#     - Printing out the variable value

# %%
articles_list[0].keys()
# Out:
# dict_keys(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'source', 'multimedia', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'subsection_name', 'byline', 'type_of_material', '_id', 'word_count', 'uri'])

# %%
for article in articles_list[0:9]:
    print(article['_id'])
    print('')
    print(article['web_url'])
    print('')
    print(article['headline']['main'])
    print('')
    print(article['document_type'])
    print('')
    print(article['pub_date'])
    print('')
    print(article['word_count'])
    print('')
    print(article['type_of_material'])
    print('')
    article_dict['nyt_article_id'].append(article['_id'])
    article_dict['web_url'].append(article['web_url'])
    article_dict['main_headline'].append(article['headline']['main'])
    article_dict['document_type'].append(article['document_type'])
    article_dict['pub_date'].append(article['pub_date'])
    article_dict['word_count'].append(article['word_count'])
    article_dict['type_of_material'].append(article['type_of_material'])
    
    print('-'*100)
# Out:
# nyt://article/5f770148-e8e9-57c9-a5b6-83f55f7cd6e0
#
# https://www.nytimes.com/2022/04/08/us/politics/january-6-investigation-ali-alexander.html
#
# Pro-Trump Rally Planner Is Cooperating in Justice Dept.’s Jan. 6 Inquiry
#
# article
#
# 2022-04-08T22:55:13+0000
#
# 1277
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/e13b44a6-540a-52da-9fc0-8e09aaa9e287
#
# https://www.nytimes.com/2022/04/08/us/politics/donald-trump-jr-meadows-text-message.html
#
# Text From Donald Trump Jr. Set Out Strategies to Fight Election Outcome
#
# article
#
# 2022-04-08T22:54:04+0000
#
# 549
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e6fae66-805f-547d-9341-548d3c05f90f
#
# https://www.nytimes.com/2022/04/08/theater/penelope-or-how-the-odyssey-was-really-written-review.html
#
# ‘Penelope’ Review: Adrift Between Ithaca and Progress
#
# article
#
# 2022-04-08T22:47:35+0000
#
# 744
#
# Review
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/d3dc8ddf-6a2d-5505-9a15-7293d117901c
#
# https://www.nytimes.com/2022/04/08/us/georgia-soldier-killing-1982.html
#
# Georgia Inmate Charged in Soldier’s Killing 40 Years Later
#
# article
#
# 2022-04-08T22:43:58+0000
#
# 531
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/ae9f155e-8b5f-5392-9d03-379fab04259c
#
# https://www.nytimes.com/2022/04/08/nyregion/redistricting-maps-new-york.html
#
# With New York District Lines On Hold, Judge Blesses Possible Backup Plan
#
# article
#
# 2022-04-08T22:37:59+0000
#
# 744
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/94cf50b9-e209-5871-976d-965f84c6a52e
#
# https://www.nytimes.com/2022/04/08/opinion/cory-booker-ketanji-brown-jackson.html
#
# Cory Booker, ‘You Had Our Back’
#
# article
#
# 2022-04-08T22:24:10+0000
#
# 1059
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/1b3e22a2-203f-52d7-9e1e-6c99ab69dceb
#
# https://www.nytimes.com/2022/04/08/us/alabama-transgender-law-ivey.html
#
# Alabama Governor Signs Ban on Transition Care for Transgender Youth
#
# article
#
# 2022-04-08T22:17:41+0000
#
# 739
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/515c5c9d-9a1c-5b93-9bde-fc07eff3c21a
#
# https://www.nytimes.com/2022/04/08/sports/baseball/aaron-judge-yankees-red-sox.html
#
# For the Yankees, a Day Finishes Better Than It Started
#
# article
#
# 2022-04-08T22:05:57+0000
#
# 1206
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/37e046d9-9f27-51c0-8db2-5cfc8fc511a6
#
# https://www.nytimes.com/2022/04/08/nyregion/trump-organization-golf-course.html
#
# Trump Organization Can Keep Operating N.Y.C. Golf Course, Judge Rules
#
# article
#
# 2022-04-08T22:05:44+0000
#
# 960
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://video/e2346a7e-c093-5887-9507-0d62be07525a
#
# https://www.nytimes.com/video/world/europe/100000008295079/ukraine-train-station-attack-video.html
#
# Missile Strike Kills at Least 50 at Train Station in Eastern Ukraine
#
# multimedia
#
# 2022-04-08T21:50:29+0000
#
# 0
#
# Video
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Print out the contents of the article details dictionary

# %%
print(article_dict)
# Out:
# {'nyt_article_id': ['nyt://article/5f770148-e8e9-57c9-a5b6-83f55f7cd6e0', 'nyt://article/e13b44a6-540a-52da-9fc0-8e09aaa9e287', 'nyt://article/0e6fae66-805f-547d-9341-548d3c05f90f', 'nyt://article/d3dc8ddf-6a2d-5505-9a15-7293d117901c', 'nyt://article/ae9f155e-8b5f-5392-9d03-379fab04259c', 'nyt://article/94cf50b9-e209-5871-976d-965f84c6a52e', 'nyt://article/1b3e22a2-203f-52d7-9e1e-6c99ab69dceb', 'nyt://article/515c5c9d-9a1c-5b93-9bde-fc07eff3c21a', 'nyt://article/37e046d9-9f27-51c0-8db2-5cfc8fc511a6', 'nyt://video/e2346a7e-c093-5887-9507-0d62be07525a'], 'web_url': ['https://www.nytimes.com/2022/04/08/us/politics/january-6-investigation-ali-alexander.html', 'https://www.nytimes.com/2022/04/08/us/politics/donald-trump-jr-meadows-text-message.html', 'https://www.nytimes.com/2022/04/08/theater/penelope-or-how-the-odyssey-was-really-written-review.html', 'https://www.nytimes.com/2022/04/08/us/georgia-soldier-killing-1982.html', 'https://www.nytimes.com/2022/04/08/nyregion/redistricting-maps-new-york.html', 'https://www.nytimes.com/2022/04/08/opinion/cory-booker-ketanji-brown-jackson.html', 'https://www.nytimes.com/2022/04/08/us/alabama-transgender-law-ivey.html', 'https://www.nytimes.com/2022/04/08/sports/baseball/aaron-judge-yankees-red-sox.html', 'https://www.nytimes.com/2022/04/08/nyregion/trump-organization-golf-course.html', 'https://www.nytimes.com/video/world/europe/100000008295079/ukraine-train-station-attack-video.html'], 'main_headline': ['Pro-Trump Rally Planner Is Cooperating in Justice Dept.’s Jan. 6 Inquiry', 'Text From Donald Trump Jr. Set Out Strategies to Fight Election Outcome', '‘Penelope’ Review: Adrift Between Ithaca and Progress', 'Georgia Inmate Charged in Soldier’s Killing 40 Years Later', 'With New York District Lines On Hold, Judge Blesses Possible Backup Plan', 'Cory Booker, ‘You Had Our Back’', 'Alabama Governor Signs Ban on Transition Care for Transgender Youth', 'For the Yankees, a Day Finishes Better Than It Started', 'Trump Organization Can Keep Operating N.Y.C. Golf Course, Judge Rules', 'Missile Strike Kills at Least 50 at Train Station in Eastern Ukraine'], 'document_type': ['article', 'article', 'article', 'article', 'article', 'article', 'article', 'article', 'article', 'multimedia'], 'pub_date': ['2022-04-08T22:55:13+0000', '2022-04-08T22:54:04+0000', '2022-04-08T22:47:35+0000', '2022-04-08T22:43:58+0000', '2022-04-08T22:37:59+0000', '2022-04-08T22:24:10+0000', '2022-04-08T22:17:41+0000', '2022-04-08T22:05:57+0000', '2022-04-08T22:05:44+0000', '2022-04-08T21:50:29+0000'], 'word_count': [1277, 549, 744, 531, 744, 1059, 739, 1206, 960, 0], 'type_of_material': ['News', 'News', 'Review', 'News', 'News', 'Op-Ed', 'News', 'News', 'News', 'Video']}

# %% [markdown]
# Assigning the article details dictionary to a dataframe

# %%
df = pd.DataFrame.from_dict(article_dict,orient='columns')

# %%
#converting the pub to a datetime 
df.pub_date = pd.to_datetime(df.pub_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nyt_article_id    10 non-null     object
#  1   web_url           10 non-null     object
#  2   main_headline     10 non-null     object
#  3   document_type     10 non-null     object
#  4   pub_date          10 non-null     datetime64[ns, UTC]
#  5   word_count        10 non-null     int64
#  6   type_of_material  10 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(1), object(5)
# memory usage: 688.0+ bytes

# %%
# Printing out the first 5 rows of the dataframe
df.head(5)
# Out:
#                                       nyt_article_id  \
# 0  nyt://article/5f770148-e8e9-57c9-a5b6-83f55f7c...
# 1  nyt://article/e13b44a6-540a-52da-9fc0-8e09aaa9...
# 2  nyt://article/0e6fae66-805f-547d-9341-548d3c05...
# 3  nyt://article/d3dc8ddf-6a2d-5505-9a15-7293d117...
# 4  nyt://article/ae9f155e-8b5f-5392-9d03-379fab04...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/04/08/us/politics...
# 1  https://www.nytimes.com/2022/04/08/us/politics...
# 2  https://www.nytimes.com/2022/04/08/theater/pen...
# 3  https://www.nytimes.com/2022/04/08/us/georgia-...
# 4  https://www.nytimes.com/2022/04/08/nyregion/re...
#
#                                        main_headline document_type  \
# 0  Pro-Trump Rally Planner Is Cooperating in Just...       article
# 1  Text From Donald Trump Jr. Set Out Strategies ...       article
# 2  ‘Penelope’ Review: Adrift Between Ithaca and P...       article
# 3  Georgia Inmate Charged in Soldier’s Killing 40...       article
# 4  With New York District Lines On Hold, Judge Bl...       article
#
#                    pub_date  word_count type_of_material
# 0 2022-04-08 22:55:13+00:00        1277             News
# 1 2022-04-08 22:54:04+00:00         549             News
# 2 2022-04-08 22:47:35+00:00         744           Review
# 3 2022-04-08 22:43:58+00:00         531             News
# 4 2022-04-08 22:37:59+00:00         744             News

# %%
df.shape
# Out:
# (10, 7)

# %% [markdown]
# Establishing a connection to my AWS EC2 sql database.
#
# Appending ?charset=utf8 to the database name to avoide codec errors.

# %%
# AWS RDS Database Connection Details
# Host: lmu-dev-01.********.us-east-2.rds.amazonaws.com
# Username: admin
# Password: ******

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqldb://admin:******@lmu-dev-01.******.us-east-2.rds.amazonaws.com/dbsql')

# %% [markdown]
# Inserting the dataframe contents to the nyt_article table previously created.
#
# Ensuring variables in the articles for loop matches the table's column names.
#
# Setting the if_exists argument to append to insert into the table already created.

# %%
df.to_sql('nyt_article',engine,if_exists='append',index=False)

# %% [markdown]
# ---

# %% [markdown]
# ### Making 10 requests to the API to collect 100 articles and saving the results to the nyt_article table
# A single API requests only returns 10 articles. Using the page parameter to "paginate" through the results.

# %%
for page in range(10):
    print('Page:', page)
        
    api_url = articles_endpoint_url
    params = {'api-key':art_key, 'page':page, 'begin_date':'20210101', 'end_date':'20211231'}

    articles_api_request = requests.get(articles_endpoint_url,params)

    articles_api_response = json.loads(articles_api_request.text)

    articles_list = articles_api_response['response']['docs']

    article_dict = {
        'nyt_article_id':[], 
        'web_url': [], 
        'main_headline': [],
        'document_type': [],
        'pub_date': [],
        'word_count': [],
        'type_of_material': []
    }

    for article in articles_list[0:10]:
        print(article['_id'])
        print('')
        print(article['web_url'])
        print('')
        print(article['headline']['main'])
        print('')
        print(article['document_type'])
        print('')
        print(article['pub_date'])
        print('')
        print(article['word_count'])
        print('')
        print(article['type_of_material'])
        print('')
        article_dict['nyt_article_id'].append(article['_id'])
        article_dict['web_url'].append(article['web_url'])
        article_dict['main_headline'].append(article['headline']['main'])
        article_dict['document_type'].append(article['document_type'])
        article_dict['pub_date'].append(article['pub_date'])
        article_dict['word_count'].append(article['word_count'])
        article_dict['type_of_material'].append(article['type_of_material'])
        
        print('-'*100)
        
    df = pd.DataFrame.from_dict(article_dict,orient='columns')
    df.pub_date = pd.to_datetime(df.pub_date)
    
    df.to_sql('nyt_article',engine,if_exists='append',index=False)
# Out:
# Page: 0
# nyt://article/0038c58f-4662-50f2-abda-65e96e8c6e0a
#
# https://www.nytimes.com/2021/12/21/technology/suicide-website-google.html
#
# Lawmakers Urge Big Tech to ‘Mitigate Harm’ of Suicide Site and Seek Justice Inquiry
#
# article
#
# 2021-12-21T10:00:18+0000
#
# 1089
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/00532bbd-6b9f-5534-80bc-2d60a84d10bb
#
# https://www.nytimes.com/2021/12/21/business/britain-pandemic-aid.html
#
# Britain offers $1.3 billion in aid to hospitality and leisure businesses.
#
# article
#
# 2021-12-21T13:44:04+0000
#
# 770
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0082094d-8beb-5f14-a56e-cc9adbec092f
#
# https://www.nytimes.com/2021/12/22/opinion/wheres-joe-biden.html
#
# Where’s Joe Biden?
#
# article
#
# 2021-12-23T01:00:07+0000
#
# 814
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/00cc6a2d-7e1d-5ca9-afd7-05936bb274ab
#
# https://www.nytimes.com/2021/12/26/arts/television/dickinson-the-great-six-feminism.html
#
# Catherine Was Great. But Was She a Girl Boss?
#
# article
#
# 2021-12-26T17:20:30+0000
#
# 1803
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0156bafd-6c15-56b2-9054-1b6482af9a85
#
# https://www.nytimes.com/2021/12/24/sports/dave-draper-dead.html
#
# Dave Draper, Bodybuilding’s ‘Blond Bomber,’ Dies at 79
#
# article
#
# 2021-12-24T13:00:07+0000
#
# 1053
#
# Obituary (Obit)
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/015ad937-6ba5-5b43-a8dc-4284b506ebad
#
# https://www.nytimes.com/2021/12/19/business/brandon-brown-lets-go-brandon.html
#
# Brandon Just Wants to Drive His Racecar
#
# article
#
# 2021-12-19T23:56:06+0000
#
# 1718
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0169e279-b817-5899-933c-ee8e04ba4a07
#
# https://www.nytimes.com/2021/12/19/us/politics/johnny-isakson-dead.html
#
# Johnny Isakson, 76, Longtime Senator From Georgia, Is Dead
#
# article
#
# 2021-12-19T17:10:13+0000
#
# 1171
#
# Obituary (Obit)
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0170929f-d79b-5f00-bfaa-bf1548b11f68
#
# https://www.nytimes.com/2021/12/23/business/intel-apology-china-xinjiang.html
#
# Intel apologizes over its statement on forced labor in Xinjiang.
#
# article
#
# 2021-12-23T11:46:20+0000
#
# 475
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0193122f-50a0-529c-9030-df9958f922f3
#
# https://www.nytimes.com/2021/12/23/briefing/coronavirus-briefing-what-happened-today.html
#
# Coronavirus Briefing: What Happened Today
#
# article
#
# 2021-12-23T22:00:06+0000
#
# 1887
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/01b85719-d9ae-51ca-b2da-841acecd2a43
#
# https://www.nytimes.com/2021/12/28/briefing/omicron-iraq-cleric.html
#
# Your Tuesday Briefing
#
# article
#
# 2021-12-28T05:49:53+0000
#
# 1162
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# Page: 1
# nyt://article/01bb4064-4a19-535c-a556-64dc479c86d6
#
# https://www.nytimes.com/2021/12/24/crosswords/spelling-bee-forum.html
#
# Spelling Bee Forum
#
# article
#
# 2021-12-24T08:00:03+0000
#
# 152
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/01df9d1b-fff1-5a13-afe6-5e15bf6ede70
#
# https://www.nytimes.com/2021/12/17/us/california-holiday-traditions.html
#
# Holiday Traditions in the Golden State
#
# article
#
# 2021-12-17T13:41:48+0000
#
# 1449
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/01e6f236-27a1-52d2-82e8-aeaff8d3234e
#
# https://www.nytimes.com/2021/12/16/realestate/housing-market-near-nyc.html
#
# Homes for Sale in New York and Connecticut
#
# article
#
# 2021-12-16T14:00:21+0000
#
# 117
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/021f8703-7921-5776-aa6d-60324b62e8b2
#
# https://www.nytimes.com/2021/12/24/todayspaper/quotation-of-the-day-omicron-sowing-doubt-and-fear-about-economy.html
#
# Quotation of the Day: Omicron Sowing Doubt and Fear About Economy
#
# article
#
# 2021-12-24T05:16:35+0000
#
# 36
#
# Quote
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/02a449ff-7080-569e-aaef-7609f9c1279d
#
# https://www.nytimes.com/2021/12/27/science/russia-nasa-spacex-asat.html
#
# NASA-Russia Alliance in Space Is Shaken by Events on Planet Earth
#
# article
#
# 2021-12-27T14:37:36+0000
#
# 1445
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/02dffa88-dd74-5612-b9ab-3f7170c64f8a
#
# https://www.nytimes.com/2021/12/22/us/politics/jim-jordan-jan-6.html
#
# Jan. 6 Panel Seeks Interview With Jim Jordan, a Close Trump Ally
#
# article
#
# 2021-12-22T21:04:48+0000
#
# 761
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0308b1e0-60a9-52ba-9735-b2da4c882828
#
# https://www.nytimes.com/2021/12/30/business/cars-brand-experience-centers.html
#
# Selling Cars, Plus Coffee, Tea or a Fancy Dinner
#
# article
#
# 2021-12-30T11:00:08+0000
#
# 1215
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0338d539-4f57-51bc-b145-d5aa9a5e78a4
#
# https://www.nytimes.com/2021/12/23/us/here-are-the-charges-that-kimberly-potter-faces.html
#
# Here are the sentences Kimberly Potter may face for her manslaughter convictions.
#
# article
#
# 2021-12-23T18:36:25+0000
#
# 297
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/03cb1974-9fa6-5010-8fb9-217df9a1197b
#
# https://www.nytimes.com/2021/12/27/nyregion/the-show-will-go-on-thanks-to-them.html
#
# The Show Will Go On, Thanks to Them
#
# article
#
# 2021-12-27T08:16:29+0000
#
# 1205
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/03e322bc-701f-577a-ac14-f87b85708e07
#
# https://www.nytimes.com/2021/12/29/nyregion/nyc-schools-testing.html
#
# New York City Looks to Test More and Keep Classrooms Open
#
# article
#
# 2021-12-29T08:49:34+0000
#
# 1553
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# Page: 2
# nyt://article/0409e657-490a-5a7b-9952-823294988025
#
# https://www.nytimes.com/2021/12/24/us/elections/democrats-state-elections.html
#
# Democrats Say They Are Serious About State Elections. But Are They Too Late?
#
# article
#
# 2021-12-24T17:55:06+0000
#
# 1614
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/041d64a1-dc94-5379-ab72-7e3299664621
#
# https://www.nytimes.com/2021/12/23/movies/a-journal-for-jordan-review.html
#
# ‘A Journal for Jordan’ Review: Reflections on Love Built and Lost
#
# article
#
# 2021-12-23T18:54:12+0000
#
# 505
#
# Review
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/042b90d5-f962-578c-8cb7-6505b321462c
#
# https://www.nytimes.com/2021/12/30/crosswords/daily-puzzle-2021-12-31.html
#
# Sudden Inspirations
#
# article
#
# 2021-12-31T03:00:04+0000
#
# 909
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/042e4694-4a40-5f4f-9f14-e1390c7052b3
#
# https://www.nytimes.com/2021/12/21/upshot/how-the-2020s-economy-could-resemble-the-1980s.html
#
# How the 2020s Economy Could Resemble the 1980s
#
# article
#
# 2021-12-21T08:00:07+0000
#
# 1420
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/046dd350-9294-5f14-8b9f-ba70b7457458
#
# https://www.nytimes.com/2021/12/31/nyregion/times-square-new-years-eve-security.html
#
# The Times Square celebration will be muted. The police presence will not.
#
# article
#
# 2021-12-31T18:45:53+0000
#
# 371
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/047b5dc2-84a2-5a8f-976f-1e0123b84915
#
# https://www.nytimes.com/2021/12/28/opinion/living-wage-calculator.html
#
# The M.I.T. Professor Defining What It Means to Live
#
# article
#
# 2021-12-28T10:00:10+0000
#
# 1374
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/049a2eae-33c4-53f9-8c27-86820080351c
#
# https://www.nytimes.com/2021/12/21/world/europe/princess-haya-sheikh-mohammed-bin.html
#
# British Court Orders Dubai Ruler to Pay £554 Million in Custody Settlement
#
# article
#
# 2021-12-21T16:39:03+0000
#
# 640
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/04a4ac34-d1d1-5284-8d91-ae393853d38f
#
# https://www.nytimes.com/2021/12/23/insider/uncovering-truths-with-missing-data.html
#
# Uncovering Truths With Missing Data
#
# article
#
# 2021-12-23T10:00:14+0000
#
# 974
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/04a901b2-7b2b-5d42-9e4c-501026b08e3d
#
# https://www.nytimes.com/2021/12/22/theater/search-for-signs-of-intelligent-life-in-the-universe.html
#
# Continuing ‘The Search for Signs of Intelligent Life in the Universe’
#
# article
#
# 2021-12-22T10:00:14+0000
#
# 2345
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/04fe8acc-1f54-5b51-bd75-342cd859e94c
#
# https://www.nytimes.com/2021/12/31/us/caron-nazario-windsor-virginia-police.html
#
# Virginia Sues Town of Windsor, Accusing It of Discriminatory Policing
#
# article
#
# 2021-12-31T16:19:10+0000
#
# 933
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 3
# nyt://article/05385c04-4ce5-50c4-bb5b-ed9ab502006c
#
# https://www.nytimes.com/2021/12/27/todayspaper/quotation-of-the-day-dubious-advice-from-tv-doctor-in-senate-hunt.html
#
# Quotation of the Day: Dubious Advice From TV Doctor in Senate Hunt
#
# article
#
# 2021-12-27T05:05:54+0000
#
# 66
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/053bde49-d10e-5bbe-8773-6bce0e01f6a4
#
# https://www.nytimes.com/2021/12/20/us/haiti-missionaries-escape.html
#
# Haiti Missionaries Describe Dramatic Escape From Kidnappers
#
# article
#
# 2021-12-20T17:36:29+0000
#
# 785
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0544c5cb-3c5c-5d2a-8b64-26be03c85974
#
# https://www.nytimes.com/2021/12/17/world/robot-drone-ban.html
#
# Killer Robots Aren’t Science Fiction. A Push to Ban Them Is Growing.
#
# article
#
# 2021-12-17T22:07:41+0000
#
# 1382
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05504efd-c7b9-54bc-84d1-fcc90f9d4608
#
# https://www.nytimes.com/2021/12/22/us/covid-college-mental-health-suicide.html
#
# Another Surge in the Virus Has Colleges Fearing a Mental Health Crisis
#
# article
#
# 2021-12-22T14:47:09+0000
#
# 1558
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05579fb5-15d6-59e0-9c74-232c5926d091
#
# https://www.nytimes.com/2021/12/17/your-money/holiday-tipping-guide.html
#
# A Guide to Holiday Tipping This Year
#
# article
#
# 2021-12-17T14:00:07+0000
#
# 1061
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0563624b-5a31-5124-b7e0-cf6f9fdbf610
#
# https://www.nytimes.com/2021/12/29/movies/maggie-gyllenhaal-lost-daughter.html
#
# Maggie Gyllenhaal Has Dangerous Ideas About Directing
#
# article
#
# 2021-12-29T10:00:17+0000
#
# 1497
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/056e864f-58a1-5179-bd33-cce016c3f3b8
#
# https://www.nytimes.com/2021/12/19/arts/music/drakeo-dead-stabbing.html
#
# Drakeo the Ruler, West Coast Rapper, Is Killed at a Los Angeles Concert
#
# article
#
# 2021-12-19T15:58:53+0000
#
# 586
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05812de4-c3de-5c90-b14c-6af63176d38e
#
# https://www.nytimes.com/2021/12/24/world/europe/covid-britain-omicron-christmas.html
#
# Despite Omicron Wave, Britons Are Set on Not Losing Another Christmas
#
# article
#
# 2021-12-24T13:23:08+0000
#
# 1147
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/058dd8c5-6122-567b-bb06-c9d3621781e7
#
# https://www.nytimes.com/2021/12/28/magazine/how-to-dig-for-clams.html
#
# How to Dig for Clams
#
# article
#
# 2021-12-28T10:00:06+0000
#
# 400
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05961af4-1fed-523e-a8c1-4221fbcf314d
#
# https://www.nytimes.com/2021/12/23/crosswords/variety-puns-and-anagrams.html
#
# Variety: Puns and Anagrams
#
# article
#
# 2021-12-24T03:02:02+0000
#
# 1101
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 4
# nyt://article/05a40a62-8287-51ed-ad8f-06df45279702
#
# https://www.nytimes.com/2021/12/17/style/sandra-sidi-ron-welch-wedding.html
#
# Life as a Pair Began at His Table for One
#
# article
#
# 2021-12-17T05:00:05+0000
#
# 681
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05c35465-1961-5ae1-849e-96c36611d5b4
#
# https://www.nytimes.com/2021/12/31/us/politics/john-roberts-supreme-court.html
#
# Chief Justice Roberts Reflects on Conflicts, Harassment and Judicial Independence
#
# article
#
# 2021-12-31T23:00:06+0000
#
# 943
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05de05cf-9654-5ed2-9cb9-e7309c6b1b84
#
# https://www.nytimes.com/2021/12/23/technology/amazon-labor-deal.html
#
# Amazon Reaches Labor Deal, Giving Workers More Power to Organize
#
# article
#
# 2021-12-23T16:24:31+0000
#
# 1146
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/05eb2515-f11b-5df8-a9a7-d200604425df
#
# https://www.nytimes.com/2021/12/18/world/asia/afghanistan-marja-economy-taliban.html
#
# Once a Symbol of U.S. Strength, an Afghan District Now Faces Dire Times
#
# article
#
# 2021-12-18T10:00:15+0000
#
# 1429
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0647748f-384e-50c7-9721-e398592d301b
#
# https://www.nytimes.com/2021/12/23/us/trump-supreme-court-jan-6.html
#
# Trump Asks Supreme Court to Block Release of Jan. 6 Records
#
# article
#
# 2021-12-23T17:21:47+0000
#
# 1047
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0655d617-a7f4-568e-bfc0-1f745f14c454
#
# https://www.nytimes.com/2021/12/29/opinion/2021-better-worse.html
#
# The ‘End of an Ending’: Was 2021 Really The Worst?
#
# article
#
# 2021-12-29T10:00:18+0000
#
# 387
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/066f9420-c8ef-5679-b42a-a001dde169db
#
# https://www.nytimes.com/2021/12/16/arts/music/juilliard-racial-disparities-gift.html
#
# $50 Million Gift to Juilliard Targets Racial Disparities in Music
#
# article
#
# 2021-12-16T16:00:09+0000
#
# 581
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0680b205-86f1-5045-a7f5-a6126f34c6f0
#
# https://www.nytimes.com/2021/12/27/dining/gran-luchito-chipotle-paste.html
#
# A Jammy Condiment With Smoky Heat
#
# article
#
# 2021-12-27T17:08:22+0000
#
# 167
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0680ddbc-2bf5-59a2-a350-c71f72103f98
#
# https://www.nytimes.com/2021/12/22/briefing/omicron-biden-inflation.html
#
# Your Wednesday Briefing
#
# article
#
# 2021-12-22T05:05:20+0000
#
# 1352
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/072c7fc1-bdf4-58b5-aa73-9c3df3539d73
#
# https://www.nytimes.com/2021/12/20/world/europe/ireland-cure-folk-medicine.html
#
# Secret Charms and 7th Sons: ‘The Cure’ Is Alive and Well in Ireland
#
# article
#
# 2021-12-20T10:00:24+0000
#
# 1296
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 5
# nyt://article/075cf494-db4d-5663-a95f-2b9b07b39fad
#
# https://www.nytimes.com/2021/12/16/technology/closing-arguments-trial-elizabeth-holmes.html
#
# Closing Arguments Begin in the Trial of Elizabeth Holmes
#
# article
#
# 2021-12-16T13:15:20+0000
#
# 1140
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/07c0cfef-a38d-5dba-b840-5f5ea7acc2a2
#
# https://www.nytimes.com/2021/12/23/us/exxon-mobil-fire-baytown-texas.html
#
# Multiple People Injured in Fire at Oil Refinery in Texas
#
# article
#
# 2021-12-23T10:46:47+0000
#
# 440
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/080c8bbd-c9cb-5cf3-91e3-648c2290a11b
#
# https://www.nytimes.com/2021/12/23/learning/word-of-the-day-replenish.html
#
# Word of the Day: replenish
#
# article
#
# 2021-12-23T07:00:03+0000
#
# 306
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/081f62e5-de85-571a-bcdd-5d60e53bd8d5
#
# https://www.nytimes.com/2021/12/18/world/a-surge-in-demand-for-virus-tests-is-swamping-the-us-system.html
#
# A surge in demand for virus tests is swamping the U.S. system.
#
# article
#
# 2021-12-18T16:41:00+0000
#
# 370
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0873fe58-dc2b-541b-96f6-4980905b67e0
#
# https://www.nytimes.com/2021/12/23/us/southwest-flight-attendant-vyvianna-quinonez-guilty.html
#
# California Woman Pleads Guilty to Punching Flight Attendant in the Face
#
# article
#
# 2021-12-23T10:00:12+0000
#
# 649
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08b26ba6-b340-5244-b45e-f837e46b32ca
#
# https://www.nytimes.com/2021/12/17/opinion/charity-philanthropy-mutual-aid.html
#
# What’s Better Than Charity?
#
# article
#
# 2021-12-17T20:16:33+0000
#
# 1685
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08bec928-6631-5071-bbe8-a2baee039aa1
#
# https://www.nytimes.com/2021/12/28/sports/college-football-holiday-bowl.html
#
# This College Bowl Season, the Toughest Opponent is the Coronavirus
#
# article
#
# 2021-12-28T21:56:45+0000
#
# 970
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08c31990-14e3-535b-b25d-4859b6d11572
#
# https://www.nytimes.com/2021/12/29/nyregion/ghislaine-maxwell-guilty-verdict.html
#
# Ghislaine Maxwell Is Found Guilty of Aiding in Epstein’s Sex Abuse
#
# article
#
# 2021-12-29T21:56:22+0000
#
# 1639
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08d2d51c-b92c-5aa7-a32a-5bee8cfc0cc9
#
# https://www.nytimes.com/2021/12/20/us/holocaust-librarian-elementary-school.html
#
# Third-Graders Instructed to Re-enact Scenes From Holocaust, Principal Says
#
# article
#
# 2021-12-20T05:26:52+0000
#
# 561
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08d6a55a-8e65-5214-acc7-80e16b49830f
#
# https://www.nytimes.com/2021/12/17/dining/torico-ice-cream-coquito.html
#
# Coquito, the Puerto Rican Holiday Drink, Available in Frozen Form
#
# article
#
# 2021-12-17T16:00:04+0000
#
# 900
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 6
# nyt://article/08f18a46-c49f-5a07-9fd2-aa7c1f239262
#
# https://www.nytimes.com/2021/12/16/arts/television/finding-magic-mike.html
#
# How Much Watching Time Do You Have This Weekend?
#
# article
#
# 2021-12-16T19:35:01+0000
#
# 372
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/08faf7c4-5fb9-594d-ac76-853ba5fb262f
#
# https://www.nytimes.com/2021/12/21/sports/olympics/nhl-olympics-beijing-hockey.html
#
# N.H.L. Players Will Skip Beijing Olympics
#
# article
#
# 2021-12-21T22:16:58+0000
#
# 743
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/092b0644-3113-5297-b0a9-16197c167313
#
# https://www.nytimes.com/2021/12/21/us/covid-schools.html
#
# Are Schools Ready for the Next Big Surge?
#
# article
#
# 2021-12-21T10:06:47+0000
#
# 1078
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/096b4c41-5968-57a9-b6f1-d09c3f9e0d8d
#
# https://www.nytimes.com/2021/12/30/business/salary-negotiation-pay.html
#
# What Do You Think You Should Be Paid?
#
# article
#
# 2021-12-30T10:00:20+0000
#
# 2156
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0989ccfd-a456-5c3f-9005-32a41ba3d829
#
# https://www.nytimes.com/2021/12/21/style/tiny-modern-love-stories-lesbian.html
#
# Tiny Love Stories: ‘Nobody Knows I’m a Lesbian’
#
# article
#
# 2021-12-21T20:00:14+0000
#
# 485
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0995f447-09dc-59ea-a182-2fb71b705823
#
# https://www.nytimes.com/2021/12/16/world/on-broadway-covid-is-trying-to-steal-every-show.html
#
# On Broadway, Covid is trying to steal every show.
#
# article
#
# 2021-12-16T14:49:32+0000
#
# 228
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/09d4ea9b-9e3f-5174-9606-f25ddfd89b52
#
# https://www.nytimes.com/2021/12/29/climate/2021-climate-year-in-review.html
#
# 2021 Climate Year in Review
#
# article
#
# 2021-12-29T18:43:14+0000
#
# 1198
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/09eb1ac7-8d74-5b7d-8e27-eb5fd6f47e06
#
# https://www.nytimes.com/2021/12/30/nyregion/omicron-covid-nyc.html
#
# Will Omicron Meet Its Match in the Perseverance of New Yorkers?
#
# article
#
# 2021-12-30T10:00:18+0000
#
# 959
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0a0db637-2704-536c-a916-e1c9d63b9f6b
#
# https://www.nytimes.com/2021/12/23/business/capital-one-hacking-settlement.html
#
# Capital One settles a class-action lawsuit for $190 million in a 2019 hacking.
#
# article
#
# 2021-12-23T21:47:45+0000
#
# 191
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0ac430cd-641a-56a3-9d06-39e70abf089d
#
# https://www.nytimes.com/2021/12/30/opinion/inflation-economy-biden-inequality.html
#
# The Missing Data in the Inflation Debate
#
# article
#
# 2021-12-30T10:00:21+0000
#
# 1153
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# Page: 7
# nyt://article/0ada66fe-3e54-5809-a81f-cb78e4915283
#
# https://www.nytimes.com/2021/12/20/technology/navigational-apps-blind-low-vision.html
#
# Navigational Apps for the Blind Could Have a Broader Appeal
#
# article
#
# 2021-12-20T10:00:10+0000
#
# 1106
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0b06a479-0fdd-523e-9d52-6524c43277c9
#
# https://www.nytimes.com/2021/12/26/crosswords/spelling-bee-forum.html
#
# Spelling Bee Forum
#
# article
#
# 2021-12-26T08:00:03+0000
#
# 186
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0b165898-cb53-5065-928f-a3b2982826d5
#
# https://www.nytimes.com/2021/12/27/world/middleeast/iraq-election-muqtada-al-sadr.html
#
# Iraq Confirms Election Gains for Shiite Leader Seen as Potential U.S. Ally
#
# article
#
# 2021-12-27T14:18:07+0000
#
# 797
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0b6fd65e-b4e4-50b2-b8ce-53854399e586
#
# https://www.nytimes.com/2021/12/24/arts/television/sex-and-the-city-girls-girlfriends-run-the-world.html
#
# It’s a ‘Sex and the City’ World. Can Carrie and Co. Still Live in It?
#
# article
#
# 2021-12-24T16:28:48+0000
#
# 1975
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0b86e29a-43de-511c-843e-9e0f51acb735
#
# https://www.nytimes.com/2021/12/22/well/fitness-alcohol-drinking-exercise.html
#
# How Exercise May Affect Our Alcohol Consumption
#
# article
#
# 2021-12-22T10:00:09+0000
#
# 980
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0baade53-056c-5385-9499-11cd7173b4d5
#
# https://www.nytimes.com/2021/12/24/sports/sailing/michael-spies-sydney-hobart.html
#
# Michael Spies Has Become Sailing’s Guru of Speed
#
# article
#
# 2021-12-24T10:00:18+0000
#
# 680
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0bad179e-7b42-5b91-a46a-07f8b31b7270
#
# https://www.nytimes.com/2021/12/30/well/eat/new-years-resolutions-food.html
#
# What Are Your Food Resolutions for the New Year?
#
# article
#
# 2021-12-31T01:00:07+0000
#
# 1127
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0beb209b-03f0-5371-93f0-be120961cd57
#
# https://www.nytimes.com/2021/12/16/learning/writing-prompt-school-shooting.html
#
# What Students Are Saying About the Parents’ Role in a Recent School Shooting
#
# article
#
# 2021-12-16T21:06:10+0000
#
# 4529
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0bee45f5-8fb7-5cb3-9955-99e63e03fcff
#
# https://www.nytimes.com/2021/12/21/briefing/asia-omicron-russia-military-tiktok-brands.html
#
# Your Wednesday Briefing: Omicron Restrictions
#
# article
#
# 2021-12-21T21:15:25+0000
#
# 1189
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0bee67df-9291-529a-8c1b-59151f6def9f
#
# https://www.nytimes.com/2021/12/22/crosswords/spelling-bee-forum.html
#
# Spelling Bee Forum
#
# article
#
# 2021-12-22T08:00:03+0000
#
# 175
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 8
# nyt://article/0c261f61-48f0-55d7-956b-e4dda312f74c
#
# https://www.nytimes.com/2021/12/19/opinion/omicron-breakthroughs.html
#
# Most Covid Infections May Soon Be Breakthroughs. Here’s What That Means.
#
# article
#
# 2021-12-19T15:05:52+0000
#
# 908
#
# Op-Ed
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0c489568-4705-50e4-9730-ba48151ad294
#
# https://www.nytimes.com/2021/12/30/books/review/kathryn-schulz-by-the-book-interview.html
#
# Kathryn Schulz Doesn’t Count Any Reading Pleasures as Guilty
#
# article
#
# 2021-12-30T10:00:03+0000
#
# 1795
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0c6db329-c254-5efa-b2e7-00bb4e3bd439
#
# https://www.nytimes.com/2021/12/21/business/tiktok-ads.html
#
# That Fun TikTok Video? It’s Actually an Ad.
#
# article
#
# 2021-12-21T10:00:15+0000
#
# 1611
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0c7c431b-4a88-5b1d-a104-4c4116c9def2
#
# https://www.nytimes.com/2021/12/31/books/review/sinclair-lewis-babbitt-main-street.html
#
# The Novelist Who Saw Middle America as It Really Was
#
# article
#
# 2021-12-31T10:00:20+0000
#
# 4509
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0ccd9fdb-0a98-5400-8e86-1d017dba0d6d
#
# https://www.nytimes.com/2021/12/28/arts/music/shane-macgowan.html
#
# Shane MacGowan Wants a Lot More of Life
#
# article
#
# 2021-12-28T15:00:10+0000
#
# 1730
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0cf78f79-ef46-500d-8b0b-e5bc08ac0d5e
#
# https://www.nytimes.com/2021/12/16/arts/design/atheneum-art-sexism-women-museum.html
#
# The Renaissance Women Who Painted Against the Odds
#
# article
#
# 2021-12-16T17:16:31+0000
#
# 1321
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0d66d989-c438-5cea-8dfa-227627265e2e
#
# https://www.nytimes.com/2021/12/29/us/politics/biden-putin-call-ukraine.html
#
# Biden and Putin Will Hold a Call on Ukraine
#
# article
#
# 2021-12-30T00:19:12+0000
#
# 869
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0d71b87f-31f0-5240-8b1f-3ddef5691331
#
# https://www.nytimes.com/2021/12/16/us/biden-migrant-family-separation-settlement.html
#
# Justice Department Halts Settlement Talks With Migrant Families
#
# article
#
# 2021-12-16T21:15:51+0000
#
# 930
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0d7d4b31-1472-51df-ba88-1974684ac008
#
# https://www.nytimes.com/2021/12/17/world/a-familiar-anxiety-returns-to-new-yorkers-as-virus-cases-surge.html
#
# A familiar anxiety returns to New Yorkers as virus cases surge.
#
# article
#
# 2021-12-17T14:03:08+0000
#
# 244
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0d8c6ebc-bb0d-5773-99ea-6410ece9c981
#
# https://www.nytimes.com/2021/12/29/nyregion/chelsea-nyc-coronavirus.html
#
# ‘Doubling Down on New York’: A Manhattan Neighborhood Bounces Back
#
# article
#
# 2021-12-29T10:00:15+0000
#
# 1614
#
# News
#
# ----------------------------------------------------------------------------------------------------
# Page: 9
# nyt://article/0d9f14f9-a368-5778-8361-9c3d7107a101
#
# https://www.nytimes.com/2021/12/16/crosswords/variety-acrostic.html
#
# Variety: Acrostic
#
# article
#
# 2021-12-17T03:02:02+0000
#
# 316
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e1c832e-8fc7-5cce-ad15-2b158553a63b
#
# https://www.nytimes.com/2021/12/22/world/what-would-it-cost-to-end-the-pandemic.html
#
# What would it cost to end the pandemic?
#
# article
#
# 2021-12-22T17:00:37+0000
#
# 488
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e2e14f3-549d-526d-96a7-31ce4058470f
#
# https://www.nytimes.com/2021/12/23/business/tesla-video-games.html
#
# Tesla agrees to stop letting drivers play video games in moving cars.
#
# article
#
# 2021-12-23T21:30:50+0000
#
# 555
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e324afc-a868-5650-9d82-5e23fe686ff1
#
# https://www.nytimes.com/2021/12/28/briefing/omicron-russia-human-rights.html
#
# Your Wednesday Briefing
#
# article
#
# 2021-12-29T04:32:56+0000
#
# 1062
#
# briefing
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e4328b4-0e54-52eb-a234-245d1163ea17
#
# https://www.nytimes.com/2021/12/29/nyregion/sacred-spaces-home-nyc.html
#
# ‘A Moment of Intimacy’: New Yorkers and the Sacred Spaces in Their Homes
#
# article
#
# 2021-12-29T10:00:25+0000
#
# 1761
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e769a5b-989a-577a-9009-7323bd0ce0bd
#
# https://www.nytimes.com/2021/12/23/us/politics/china-uyghurs-forced-labor.html
#
# U.S. Effort to Combat Forced Labor Targets Corporate China Ties
#
# article
#
# 2021-12-23T16:53:27+0000
#
# 1659
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0e969083-afba-5a47-925f-c8e5aee38cf9
#
# https://www.nytimes.com/2021/12/22/nyregion/de-blasio-report-card-inequity.html
#
# 6 Numbers That Reveal Bill de Blasio’s Legacy on Inequality
#
# article
#
# 2021-12-22T10:02:33+0000
#
# 2133
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0eef54ad-704e-5ad8-aea8-dc55b8335dd3
#
# https://www.nytimes.com/2021/12/30/insider/is-there-such-a-thing-as-a-slow-news-week.html
#
# Is There Such a Thing as a Slow News Week?
#
# article
#
# 2021-12-30T10:00:12+0000
#
# 945
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0ef8989e-b987-5be3-9ddb-5195b99f75db
#
# https://www.nytimes.com/2021/12/31/us/pentagon-airstrikes-syria-iraq.html
#
# Documents Reveal Basic Flaws in Pentagon Dismissals of Civilian Casualty Claims
#
# article
#
# 2021-12-31T23:25:54+0000
#
# 2098
#
# News
#
# ----------------------------------------------------------------------------------------------------
# nyt://article/0efb90dc-d9f9-5e20-b464-1ea5ad80b01c
#
# https://www.nytimes.com/2021/12/17/movies/naples-hand-of-god.html
#
# Naples, a City of Contradictions, Is Once Again a Home for Cinema
#
# article
#
# 2021-12-17T15:57:00+0000
#
# 1178
#
# News
#
# ----------------------------------------------------------------------------------------------------
