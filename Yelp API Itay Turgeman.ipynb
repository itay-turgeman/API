# %% [markdown]
# #### This file shows the ability to use API to get data and structure it in a dataframe
# - Used the following libraries:
# - To make an API request - requests
# - To decode JSON - json
# - To save data to a dataframe - pandas

# %%
# Import package to make HTTP requests, i.e. fetch URL similar to a browser request
import requests
# Import json library to JSON
import json
# Import pandas
import pandas as pd

# %%
# API endpoint
api_url = 'https://api.yelp.com/v3/businesses/search'

# what we're searching for
params = {'term' : 'tacos', 'location':'90405'}

# authentication
api_key = '*************'
headers ={'Authorization':f'Bearer {api_key}'}
# make API request
api_request = requests.get(api_url, params=params, headers=headers)

# %%
api_request
# Out:
# <Response [200]>

# %%
api_request.text
# Out:
# '{"businesses": [{"id": "isByA9pvNBtUa4Joi60O5w", "alias": "el-primo-tacos-venice", "name": "El Primo Tacos", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/3yloIs6kEaWJTWTnG8bckw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/el-primo-tacos-venice?adjust_creative=BbAjz905AQmSlvN6zimnQA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BbAjz905AQmSlvN6zimnQA", "review_count": 324, "categories": [{"alias": "streetvendors", "title": "Street Vendors"}, {"alias": "tacos", "title": "Tacos"}], "rating": 5.0, "coordinates": {"latitude": 33.998511, "longitude": -118.462557}, "transactions": [], "price": "$", "location": {"address1": "845 Lincoln Blvd", "address2": "", "address3": null, "city": "Venice", "zip_code": "90291", "country": "US", "state": "CA", "display_address": ["845 Lincoln Blvd", "Venice, CA 90291"]}, "phone": "", "display_phone": "", "distance": 1559.2424186243675}, {"id": "kSku7_iE67w7lIWU5qH4qA", "alias": "tacos-por-favor-santa-monica", "name": "Tacos Por Favor", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/P3Y07CeELCpIT6wlPKLPPQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/tacos-por-favor-santa-monica?adjust_creative=BbAjz905AQmSlvN6zimnQA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BbAjz905AQmSlvN6zimnQA", "review_count": 1609, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.0, "coordinates": {"latitude": 34.019676, "longitude": -118.480252}, "transactions": ["delivery", "pickup"], "price": "$", "location": {"address1": "1408 Olympic Blvd", "address2": "", "address3": "", "city": "Santa Monica", "zip_code": "90404", "country": "US", "state": "CA", "display_address": ["1408 Olympic Blvd", "Santa Monica, CA 90404"]}, "phone": "+13103925768", "display_phone": "(310) 392-5768", "distance": 1413.5887558885768}, {"id": "o7NYe_JTnouNJUHTM5i9zg", "alias": "samo-s-oaxaca-santa-monica", "name": "SaMo\\u2019s Oaxaca", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/82Z_PoCng5M8zEZJsNpxFg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/samo-s-oaxaca-santa-monica?adjust_creative=BbAjz905AQmSlvN6zimnQA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BbAjz905AQmSlvN6zimnQA", "review_count": 202, "categories": [{"alias": "mexican", "title": "Mexican"}, {"alias": "breakfast_brunch", "title": "Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": 34.01277467, "longitude": -118.48299017}, "transactions": ["delivery", "pickup"], "price": "$", "location": {"address1": "1865 Lincoln Blvd", "address2": null, "address3": null, "city": "Santa Monica", "zip_code": "90404", "country": "US", "state": "CA", "display_address": ["1865 Lincoln Blvd", "Santa Monica, CA 90404"]}, "phone": "+14243228370", "display_phone": "(424) 322-8370", "distance": 1357.977704433089}, {"id": "RRBx1fD9KFVOHS0qkSOS4g", "alias": "new-bootleg-taco-stand-on-venice-los-angeles", "name": "New Bootleg Taco Stand on Venice", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/M_g34FJaAyaL--yrPzWT4Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/new-bootleg-taco-stand-on-venice-los-angeles?adjust_creative=BbAjz905AQmSlvN6zimnQA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BbAjz905AQmSlvN6zimnQA", "review_count": 70, "categories": [{"alias": "tacos", "title": "Tacos"}, {"alias": "streetvendors", "title": "Street Vendors"}], "rating": 4.5, "coordinates": {"latitude": 34.001126, "longitude": -118.469817}, "transactions": [], "price": "$", "location": {"address1": "225 Lincoln Blvd", "address2": "", "address3": null, "city": "Los Angeles", "zip_code": "90291", "country": "US", "state": "CA", "display_address": ["225 Lincoln Blvd", "Los Angeles, CA 90291"]}, "phone": "", "display_phone": "", "distance": 1182.2585444271135}, {"id": "RSR6uGDvhWQDmsDqylMAWw", "alias": "tacos-la-guerra-los-angeles", "name": "Tacos La ...

# %%
# Converting the requesting text into a JSON dictionary
api_response = json.loads(api_request.text)

# %%
# Sanity check
type(api_response)
# Out:
# dict

# %%
businesses = api_response['businesses']

# %%
# Verifying the type is a list
type(businesses)
# Out:
# list

# %% [markdown]
# ---

# %%
# Inserting the JSON list file into a dataframe
df = pd.DataFrame(businesses)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20 non-null     object
#  1   alias          20 non-null     object
#  2   name           20 non-null     object
#  3   image_url      20 non-null     object
#  4   is_closed      20 non-null     bool
#  5   url            20 non-null     object
#  6   review_count   20 non-null     int64
#  7   categories     20 non-null     object
#  8   rating         20 non-null     float64
#  9   coordinates    20 non-null     object
#  10  transactions   20 non-null     object
#  11  price          19 non-null     object
#  12  location       20 non-null     object
#  13  phone          20 non-null     object
#  14  display_phone  20 non-null     object
#  15  distance       20 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 2.5+ KB

# %%
df.shape
# Out:
# (20, 16)

# %%
# extracting the columns names from the 'locations'
df.location.array[0]
# Out:
# {'address1': '845 Lincoln Blvd',
#  'address2': '',
#  'address3': None,
#  'city': 'Venice',
#  'zip_code': '90291',
#  'country': 'US',
#  'state': 'CA',
#  'display_address': ['845 Lincoln Blvd', 'Venice, CA 90291']}

# %% [markdown]
# Splitting the nested dict in location into a list and then concat the lists; similar to JOIN in SQL.

# %%
address = pd.DataFrame(df['location'].tolist(), columns =['address1','address2','address3','city','zip_code','country','state','display_address'])

# %%
df = pd.concat([df,address],axis=1)
df.head()
# Out:
#                        id                                         alias  \
# 0  isByA9pvNBtUa4Joi60O5w                         el-primo-tacos-venice
# 1  kSku7_iE67w7lIWU5qH4qA                  tacos-por-favor-santa-monica
# 2  o7NYe_JTnouNJUHTM5i9zg                    samo-s-oaxaca-santa-monica
# 3  RRBx1fD9KFVOHS0qkSOS4g  new-bootleg-taco-stand-on-venice-los-angeles
# 4  RSR6uGDvhWQDmsDqylMAWw                   tacos-la-guerra-los-angeles
#
#                                name  \
# 0                    El Primo Tacos
# 1                   Tacos Por Favor
# 2                     SaMo’s Oaxaca
# 3  New Bootleg Taco Stand on Venice
# 4                   Tacos La Guerra
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/3yloIs...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/P3Y07C...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/82Z_Po...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/M_g34F...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/CCjo5H...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/el-primo-tacos-venice...           324
# 1  https://www.yelp.com/biz/tacos-por-favor-santa...          1609
# 2  https://www.yelp.com/biz/samo-s-oaxaca-santa-m...           202
# 3  https://www.yelp.com/biz/new-bootleg-taco-stan...            70
# 4  https://www.yelp.com/biz/tacos-la-guerra-los-a...            11
#
#                                           categories  rating  \
# 0  [{'alias': 'streetvendors', 'title': 'Street V...     5.0
# 1  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.0
# 2  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     4.5
# 3  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.5
# 4  [{'alias': 'tacos', 'title': 'Tacos'}, {'alias...     4.5
#
#                                          coordinates  ...   display_phone  \
# 0  {'latitude': 33.998511, 'longitude': -118.462557}  ...
# 1  {'latitude': 34.019676, 'longitude': -118.480252}  ...  (310) 392-5768
# 2  {'latitude': 34.01277467, 'longitude': -118.48...  ...  (424) 322-8370
# 3  {'latitude': 34.001126, 'longitude': -118.469817}  ...
# 4  {'latitude': 34.0019788912789, 'longitude': -1...  ...
#
#       distance           address1 address2 address3          city zip_code  \
# 0  1559.242419   845 Lincoln Blvd              None        Venice    90291
# 1  1413.588756  1408 Olympic Blvd                    Santa Monica    90404
# 2  1357.977704  1865 Lincoln Blvd     None     None  Santa Monica    90404
# 3  1182.258544   225 Lincoln Blvd              None   Los Angeles    90291
# 4  1085.055190   241 Lincoln Blvd              None   Los Angeles    90291
#
#   country state                              display_address
# 0      US    CA         [845 Lincoln Blvd, Venice, CA 90291]
# 1      US    CA  [1408 Olympic Blvd, Santa Monica, CA 90404]
# 2      US    CA  [1865 Lincoln Blvd, Santa Monica, CA 90404]
# 3      US    CA    [225 Lincoln Blvd, Los Angeles, CA 90291]
# 4      US    CA    [241 Lincoln Blvd, Los Angeles, CA 90291]
#
# [5 rows x 24 columns]

# %%
df = df.loc[:,['name','rating','address1','city','state','zip_code','url','id']].sort_values('name')

# %%
df.head()
# Out:
#                                                  name  rating  \
# 6   Benny's Tacos & Rotisserie Chicken - Santa Monica     4.5
# 12                                    Blue Plate Taco     4.0
# 10                             Brothers Cousins Tacos     5.0
# 8                                             Chulita     4.5
# 14                                             Clutch     4.0
#
#                address1          city state zip_code  \
# 6     915 Wilshire Blvd  Santa Monica    CA    90401
# 12       1515 Ocean Ave  Santa Monica    CA    90401
# 10  11341 National Blvd   Los Angeles    CA    90064
# 8          533 Rose Ave        Venice    CA    90291
# 14     427 Lincoln Blvd        Venice    CA    90291
#
#                                                   url                      id
# 6   https://www.yelp.com/biz/bennys-tacos-and-roti...  43ysRFneqcfKSX3IbwyDGA
# 12  https://www.yelp.com/biz/blue-plate-taco-santa...  WIoii7lpw4fjWbYnBT-VPA
# 10  https://www.yelp.com/biz/brothers-cousins-taco...  Lu2osODR3Cu9kTfaav3JiQ
# 8   https://www.yelp.com/biz/chulita-venice?adjust...  OCkQdKMHU-LwWTWNe5leBA
# 14  https://www.yelp.com/biz/clutch-venice-4?adjus...  btrKlyl6kbJ3-jh-SKXH_A

# %%
# save df to a csv file

df.to_csv('yelp_tacos_90045.csv', index=False)
